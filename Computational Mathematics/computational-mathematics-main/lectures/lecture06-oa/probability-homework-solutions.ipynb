# %% [markdown]
# # Computational Mathematics  <a class="tocSkip">
#
# ## Probability (and some first steps towards Machine Learning) <a class="tocSkip">
#
# ### Homework Exercises - Solutions <a class="tocSkip">

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Homework" data-toc-modified-id="Homework-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Homework</a></span><ul class="toc-item"><li><span><a href="#Homework---Covariance-matrices-for-the-Iris-flowers-per-species" data-toc-modified-id="Homework---Covariance-matrices-for-the-Iris-flowers-per-species-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Homework - Covariance matrices for the Iris flowers per species</a></span><ul class="toc-item"><li><span><a href="#Solution---Covariance-matrices-for-the-Iris-flowers-per-species" data-toc-modified-id="Solution---Covariance-matrices-for-the-Iris-flowers-per-species-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Solution - Covariance matrices for the Iris flowers per species</a></span></li></ul></li><li><span><a href="#Homework---Computing-the-covariance-matrix" data-toc-modified-id="Homework---Computing-the-covariance-matrix-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Homework - Computing the covariance matrix</a></span><ul class="toc-item"><li><span><a href="#Solution---Computing-the-covariance-matrix" data-toc-modified-id="Solution---Computing-the-covariance-matrix-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Solution - Computing the covariance matrix</a></span></li></ul></li><li><span><a href="#Homework---Die-rolling-experiment" data-toc-modified-id="Homework---Die-rolling-experiment-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Homework - Die-rolling experiment</a></span><ul class="toc-item"><li><span><a href="#Solution---Die-rolling-experiment" data-toc-modified-id="Solution---Die-rolling-experiment-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Solution - Die-rolling experiment</a></span></li></ul></li><li><span><a href="#Homework---The-Gaussian-integral" data-toc-modified-id="Homework---The-Gaussian-integral-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Homework - The Gaussian integral</a></span><ul class="toc-item"><li><span><a href="#Solution---The-Gaussian-integral" data-toc-modified-id="Solution---The-Gaussian-integral-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Solution - The Gaussian integral</a></span></li></ul></li><li><span><a href="#Homework---Normal-distribution-plotting" data-toc-modified-id="Homework---Normal-distribution-plotting-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Homework - Normal distribution plotting</a></span><ul class="toc-item"><li><span><a href="#Solution---Normal-distribution-plotting" data-toc-modified-id="Solution---Normal-distribution-plotting-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Solution - Normal distribution plotting</a></span></li></ul></li><li><span><a href="#Homework---Cumulative-distribution/density-function-(CDF)" data-toc-modified-id="Homework---Cumulative-distribution/density-function-(CDF)-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Homework - Cumulative distribution/density function (CDF)</a></span><ul class="toc-item"><li><span><a href="#Solution---CDF" data-toc-modified-id="Solution---CDF-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Solution - CDF</a></span></li></ul></li><li><span><a href="#Homework---Monte-Carlo-simulation-[$\star$]" data-toc-modified-id="Homework---Monte-Carlo-simulation-[$\star$]-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Homework - Monte-Carlo simulation [$\star$]</a></span><ul class="toc-item"><li><span><a href="#Solution---Monte-Carlo-simulation" data-toc-modified-id="Solution---Monte-Carlo-simulation-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Solution - Monte-Carlo simulation</a></span></li></ul></li><li><span><a href="#Homework---Naive-Bayes-classifier" data-toc-modified-id="Homework---Naive-Bayes-classifier-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Homework - Naive Bayes classifier</a></span><ul class="toc-item"><li><span><a href="#Solution---Naive-Bayes-classifier" data-toc-modified-id="Solution---Naive-Bayes-classifier-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Solution - Naive Bayes classifier</a></span></li></ul></li><li><span><a href="#Homework----Maximum-likelihood-estimation--[$\star\star$]" data-toc-modified-id="Homework----Maximum-likelihood-estimation--[$\star\star$]-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Homework -  Maximum likelihood estimation  [$\star\star$]</a></span><ul class="toc-item"><li><span><a href="#Solution----Maximum-likelihood-estimation" data-toc-modified-id="Solution----Maximum-likelihood-estimation-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>Solution -  Maximum likelihood estimation</a></span></li></ul></li><li><span><a href="#Homework---The-logistic-function-and-its-derivative" data-toc-modified-id="Homework---The-logistic-function-and-its-derivative-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Homework - The logistic function and its derivative</a></span><ul class="toc-item"><li><span><a href="#Solution---The-logistic-function-and-its-derivative" data-toc-modified-id="Solution---The-logistic-function-and-its-derivative-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>Solution - The logistic function and its derivative</a></span></li></ul></li><li><span><a href="#Homework---PCA-for-the-Iris-dataset-[$\star\star$]" data-toc-modified-id="Homework---PCA-for-the-Iris-dataset-[$\star\star$]-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Homework - PCA for the Iris dataset [$\star\star$]</a></span><ul class="toc-item"><li><span><a href="#Try-implementing-things-yourself-to-&quot;demystify&quot;-a-little-what-scikit-learn-is-doing-under-the-hood" data-toc-modified-id="Try-implementing-things-yourself-to-&quot;demystify&quot;-a-little-what-scikit-learn-is-doing-under-the-hood-1.11.1"><span class="toc-item-num">1.11.1&nbsp;&nbsp;</span>Try implementing things yourself to "demystify" a little what scikit-learn is doing under the hood</a></span></li><li><span><a href="#Solution---PCA-for-the-Iris-dataset---first-via-SVD" data-toc-modified-id="Solution---PCA-for-the-Iris-dataset---first-via-SVD-1.11.2"><span class="toc-item-num">1.11.2&nbsp;&nbsp;</span>Solution - PCA for the Iris dataset - first via SVD</a></span></li><li><span><a href="#Solution---Now-instead-starting-from-the-covariance-matrix" data-toc-modified-id="Solution---Now-instead-starting-from-the-covariance-matrix-1.11.3"><span class="toc-item-num">1.11.3&nbsp;&nbsp;</span>Solution - Now instead starting from the covariance matrix</a></span></li><li><span><a href="#Solution---The-annoying-sign-issue" data-toc-modified-id="Solution---The-annoying-sign-issue-1.11.4"><span class="toc-item-num">1.11.4&nbsp;&nbsp;</span>Solution - The annoying sign issue</a></span></li></ul></li></ul></li></ul></div>

# %%
# %%html
# <style>
# div.optional {
#     display: block;
#     background-color: #d7e2ff;
#     border-color: #d7e2ff;
#     border-left: 5px solid #d7e2ff;
#     padding: 0.5em;
# }
# div.advanced {
#     display: block;
#     background-color: #fff4d7;
#     border-color: #fff4d7;
#     border-left: 5px solid #fff4d7;
#     padding: 0.5em;
# }
# </style>
# Out:
# <style>
# div.optional {
#     display: block;
#     background-color: #d7e2ff;
#     border-color: #d7e2ff;
#     border-left: 5px solid #d7e2ff;
#     padding: 0.5em;
# }
# div.advanced {
#     display: block;
#     background-color: #fff4d7;
#     border-color: #fff4d7;
#     border-left: 5px solid #fff4d7;
#     padding: 0.5em;
# }
# </style>

# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
# https://seaborn.pydata.org/
# "Seaborn is a Python data visualization library based on matplotlib. 
# It provides a high-level interface for drawing attractive and informative statistical graphics."
import seaborn as sns
# switch to seaborn figure aesthetic defaults
#sns.set_theme()
sns.set()

# %% [markdown]
# # Homework

# %% [markdown]
# ## Homework - Covariance matrices for the Iris flowers per species
#
# Recreate the covariance "eye-ball" correlation guessing and associated calculation for each Iris flower species in turn, i.e. do it on a per-colour basis.

# %% [markdown]
# ### Solution - Covariance matrices for the Iris flowers per species

# %%
from sklearn.datasets import load_iris

iris = load_iris()

irisdf = pd.DataFrame(data=np.c_[iris['data'], iris['target']],
                      columns=iris['feature_names'] + ['target'])

# %%
# recall the target names - the species
print(iris['target_names'])
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
iris_setosa_df = irisdf.loc[irisdf['target'] == 0]

sns.pairplot(iris_setosa_df, vars=iris_setosa_df[:-1])

# %%
iris_setosa_df.iloc[:, :-1].cov()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           0.124249          0.099216           0.016355
# sepal width (cm)            0.099216          0.143690           0.011698
# petal length (cm)           0.016355          0.011698           0.030159
# petal width (cm)            0.010331          0.009298           0.006069
#
#                    petal width (cm)
# sepal length (cm)          0.010331
# sepal width (cm)           0.009298
# petal length (cm)          0.006069
# petal width (cm)           0.011106

# %%
iris_versicolor_df = irisdf.loc[irisdf['target'] == 1]

sns.pairplot(iris_versicolor_df, vars=iris_versicolor_df.columns[:-1])

# %%
iris_versicolor_df.iloc[:, :-1].cov()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           0.266433          0.085184           0.182898
# sepal width (cm)            0.085184          0.098469           0.082653
# petal length (cm)           0.182898          0.082653           0.220816
# petal width (cm)            0.055780          0.041204           0.073102
#
#                    petal width (cm)
# sepal length (cm)          0.055780
# sepal width (cm)           0.041204
# petal length (cm)          0.073102
# petal width (cm)           0.039106

# %%
iris_virginica_df = irisdf.loc[irisdf['target'] == 2]

sns.pairplot(iris_virginica_df, vars=iris_virginica_df.columns[:-1])

# %% [markdown]
# ## Homework - Computing the covariance matrix
#
# Recall from class we used Pandas `cov()` to compute the covariance matrix for the first four data columns of the Iris dataset (repeated in next well).
#
# Of course this is convenient, but doesn't help confirm out mathematical understanding of what is going on.
#
# Try computing this $4\times 4$ matrix yourself from first principles using NumPy alone (and not using NumPy's `cov()`!!
#
# Speccifically, convert the Pandas data frame for the first 4 columns of data to a NumPy array (which should then be of size 50 x 4)

# %%
iris_virginica_df.iloc[:, :-1].cov()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           0.404343          0.093763           0.303290
# sepal width (cm)            0.093763          0.104004           0.071380
# petal length (cm)           0.303290          0.071380           0.304588
# petal width (cm)            0.049094          0.047629           0.048824
#
#                    petal width (cm)
# sepal length (cm)          0.049094
# sepal width (cm)           0.047629
# petal length (cm)          0.048824
# petal width (cm)           0.075433

# %% [markdown]
# ### Solution - Computing the covariance matrix

# %%
# extract the first four columns and covert to numpy array
X = iris_virginica_df.iloc[:, :-1].to_numpy()

# NB. If you wanted to cheat with numpy you could execute
#print(np.cov(X.T))
#print(np.cov(X, rowvar=False))


# But we're going to do it following the math
# Start by subtracting the mean from each column
Xc = X - X.mean(axis=0, keepdims=True)

# Covariance matrix should then be defined as (1/n) X.T @ X  
# (or perhaps 1/(n-1) depending on implementation)

# (n = Xc.shape[0] should be 50 as 50 rows(data points)
C = (1/Xc.shape[0]) * Xc.T @ Xc

print(C)

# That was a little out. Let's try 1/(n-1):

C = (1/(Xc.shape[0]-1)) * Xc.T @ Xc

print(C)

# Compare with above
print(np.allclose(C, iris_virginica_df.iloc[:, :-1].cov().to_numpy()))

# Success!!
# Out:
# [[0.396256 0.091888 0.297224 0.048112]
#  [0.091888 0.101924 0.069952 0.046676]
#  [0.297224 0.069952 0.298496 0.047848]
#  [0.048112 0.046676 0.047848 0.073924]]
# [[0.40434286 0.09376327 0.3032898  0.04909388]
#  [0.09376327 0.10400408 0.07137959 0.04762857]
#  [0.3032898  0.07137959 0.30458776 0.04882449]
#  [0.04909388 0.04762857 0.04882449 0.07543265]]
# True

# %% [markdown]
# ## Homework - Die-rolling experiment
#
# Investigate how the probabilities computed for the die-rolling experiment equalise as you increase the number of times you roll the die.

# %% [markdown]
# ### Solution - Die-rolling experiment

# %%
def dice_experiment(n):
    # set the seed to make the random experiment reproducible
    # if you exclude this you should get a different result each time you run
    # np.random.seed(1)
    # return n rolls from the S = {1, 2, 3, 4, 5, 6} sample space
    return np.random.randint(low=1, high=7, size=n)

def probabilities(outcomes):
    # Extract the number of occurences for each outcome
    values, counts = np.unique(outcomes, return_counts=True)
    n = len(outcomes)  # total number of outcomes   
    return values, counts/n

def plot_probability_mass_function(values, probabilities):
    # Plot the probability mass function
    plt.stem(values, probabilities, use_line_collection=True)

    # Axis labels
    plt.xlabel(r'$x$')
    plt.ylabel(r'$P(x)$')

    # Ensure that ticks are displayed with the right step
    ax = plt.gca()
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(0.1))

    plt.show()

# %%
n = 1_000_000
outcomes = dice_experiment(n)
plot_probability_mass_function(*probabilities(outcomes))

# we could gauge how equal these are by finding the different between the max 
# probability and the smallest
print(np.max(probabilities(outcomes)[1]) - np.min(probabilities(outcomes)[1]))
# Out:
# 0.0008150000000000102

# %%
# and see how this metric reduces as we roll the die more times
for n in 10**np.arange(8):
    outcomes = dice_experiment(n)
    print(n, np.max(probabilities(outcomes)[1]) - np.min(probabilities(outcomes)[1]))
# Out:
# 1 0.0
# 10 0.19999999999999998
# 100 0.14
# 1000 0.04099999999999998
# 10000 0.007699999999999985
# 100000 0.0011399999999999744
# 1000000 0.0010700000000000154
# 10000000 0.00015780000000001349

# %% [markdown]
# ## Homework - The Gaussian integral
#
# A useful definite integral to know is the area under the function $e^{-x^2}$ over the whole real line:
#
# $$\int_{-\infty}^{\infty} e^{-x^2}\, dx = \sqrt{\pi}$$
#
# This result is known as the [Gaussian integral](https://en.wikipedia.org/wiki/Gaussian_integral>).
#
# Read the description at the above link for how this integral can be (relatively) easily established if you know about polar coordinates and know the "trick".
#
# <br>
#
# Once we have this key result we can establish that
#
# $$\int_{-\infty}^{\infty} e^{-\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2 }\, dx = \sigma\sqrt{2\pi}$$
#
# and thus by dividing through by the quantity on the RHS we have a function
#
# $$f(x) = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2 }$$
#
# (note that this is the [**Gaussian function**](https://en.wikipedia.org/wiki/Gaussian_function))which has the property that its integral over the entire real line is unity.
#
# <br>
#
# Can you see how to establish that
#
# $$\int_{-\infty}^{\infty} e^{-x^2}\, dx = \sqrt{\pi}
# \implies
# \int_{-\infty}^{\infty} e^{-\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2 }\, dx = \sigma\sqrt{2\pi}
# $$
#
# through two changes of variables?

# %% [markdown]
# ### Solution - The Gaussian integral
#
# We do this be change of variables. Starting from
#
# $$\int_{-\infty}^{\infty} e^{-x^2}\, dx = \sqrt{\pi} $$
#
# introduce the new variable
#
# $$y:= \sqrt{2} x \implies x = \frac{y}{\sqrt{2}},
# \quad \text{and}\quad \frac{dy}{dx}={\sqrt{2}}\implies dx = \frac{1}{\sqrt{2}}dy
# $$
#
# we also need to remember to note that the limits of the integral $x\rightarrow \pm\infty$ transform to $y\rightarrow \pm\infty$.  We can then transform the variables in the integral:
#
# $$\sqrt{\pi} = \int_{-\infty}^{\infty} e^{-x^2}\, dx =
# \int_{-\infty}^{\infty} e^{-\frac{1}{2} y^2}\, \frac{1}{\sqrt{2}}\, dy
# =\frac{1}{\sqrt{2}} \int_{-\infty}^{\infty} e^{-\frac{1}{2} y^2}\, dy
# $$
#
# and hence
#
# $$\int_{-\infty}^{\infty} e^{-\frac{1}{2} y^2} \, dy = \sqrt{2} \sqrt{\pi}
# =\sqrt{2\pi}$$
#
# Note that $y$ here is a [*dummy variable*](https://mathworld.wolfram.com/DummyVariable.html)
# and so we could replace it here with $x$ (which in the original integral was also a dummy variable of course) if we wanted, but we won't do this yet as we're not finished.
#
# Let's make the further change of variables
#
# $$z:= \sigma\, y + \mu \implies y = \frac{z - \mu}{\sigma},
# \quad \text{and}\quad \frac{dz}{dy}=\sigma \implies dy = \frac{1}{\sigma}dz
# $$
#
# again we need to note that  $y\rightarrow \pm\infty$ transforms to $z\rightarrow \pm\infty$ (as we can assume that $\sigma>0$.
#
# We therefore have that
#
# $$\sqrt{2\pi} = \int_{-\infty}^{\infty} e^{-\frac{1}{2} y^2} \, dy
# =\int_{-\infty}^{\infty} e^{-\frac{1}{2} \left(\frac{z - \mu}{\sigma}\right)^2} \,\frac{1}{\sigma}\, dz
# $$
#
# and therefore
#
# $$\int_{-\infty}^{\infty} e^{-\frac{1}{2} \left(\frac{z - \mu}{\sigma}\right)^2} \, dz
# = \sigma\sqrt{2\pi}
# $$
#
# We can replace our dummy variable ($z$ here) with a different symbol (let's choose $x$), and we have that
#
# $$\frac{1}{\sigma\sqrt{2\pi}}\int_{-\infty}^{\infty} e^{-\frac{1}{2} \left(\frac{x - \mu}{\sigma}\right)^2} \, dx
# = 1
# $$
#
# i.e. the function
#
# $$f(x) := \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2 }$$
#
# has the property that
#
# $$\int_{-\infty}^{\infty} f(x) \, dx = 1 $$

# %% [markdown]
# ## Homework - Normal distribution plotting
#
# As mentioned in class, take the code that randomly draws data from a normal distribution, plot it with different numbers of bins, sample size etc, and check how well it agrees with the normal distribution/Gaussian function.

# %% [markdown]
# ### Solution - Normal distribution plotting

# %%
# set the seed to make the random experiment reproducible
np.random.seed(1)

mean = 0
standard_deviation = 0.1
n = 100_000

# Draw outcomes from a normal distribution
outcomes = np.random.normal(loc=mean, scale=standard_deviation, size=n)

# Plot histogram
nbins = 30
hist = plt.hist(outcomes, bins=nbins, range=(-0.5, 0.5))

# Set the ticks step size
#ax = plt.gca()
#ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))


# Define the normal distribution
normal_distribution = st.norm(mean, standard_deviation)

# Compute PDF values at a sequence of x locations between -1 and 1
x_values = np.linspace(-1, 1, 100)
y_values = normal_distribution.pdf(x_values)

# Plot PDF
# note the scaling I make here to get the height of the Gaussian correct
plt.plot(x_values, n/nbins*y_values, 'r')
plt.xlabel(r'$x$')
plt.ylabel(r'Count')
plt.show()


plt.show()

# %% [markdown]
# Alternatively, use the optional argument "density" with `hist`.

# %%
# set the seed to make the random experiment reproducible
np.random.seed(1)

mean = 0
standard_deviation = 0.1
n = 100_000

# Draw outcomes from a normal distribution
outcomes = np.random.normal(loc=mean, scale=standard_deviation, size=n)

# Plot histogram
nbins = 30
hist = plt.hist(outcomes, bins=nbins, range=(-0.5, 0.5), density=True)

# Set the ticks step size
#ax = plt.gca()
#ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))


# Define the normal distribution
normal_distribution = st.norm(mean, standard_deviation)

# Compute PDF values at a sequence of x locations between -1 and 1
x_values = np.linspace(-1, 1, 100)
y_values = normal_distribution.pdf(x_values)

# Plot PDF
plt.plot(x_values, y_values, 'r')
plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.show()


plt.show()

# %% [markdown]
# ## Homework - Cumulative distribution/density function (CDF)
#
# Recall the following plot from the lecture that used `normal_distribution.cdf`.
#
# Recreate this plot using only data obtained from `normal_distribution.pdf` and the mathematical definition of the CDF in terms of the PDF.

# %%
mean = 0
standard_deviation = 0.1

# Define the normal distribution
normal_distribution = st.norm(mean, standard_deviation)

# Compute CDF values at a sequence of x locations between -1 and 1
x_values = np.linspace(-1, 1, 100)
y_values = normal_distribution.cdf(x_values)

# Plot PDF
plt.plot(x_values, y_values)
plt.xlabel(r'$x$')
plt.ylabel(r'$P(X\leq x)$')
plt.show()

# %% [markdown]
# ### Solution - CDF

# %%
mean = 0
standard_deviation = 0.1

# Define the normal distribution
normal_distribution = st.norm(mean, standard_deviation)

# Compute CDF values at a sequence of x locations between -1 and 1
x_values = np.linspace(-1, 1, 100)
# what's the distance between our x values, i.e. out dx
dx = x_values[1]-x_values[0]
# set up an array of the right size made up up of zeros
y_values = np.zeros_like(x_values)
# now work from left to right summing the pdf values multiplied by the x spacing
# skip the first entry which is zero
for i, x in enumerate(x_values[1:]):
    y_values[i+1] = y_values[i] + normal_distribution.pdf(x_values[i+1])*dx

# Plot PDF
plt.plot(x_values, y_values)
plt.xlabel(r'$x$')
plt.ylabel(r'$P(X\leq x)$')
plt.show()

# %% [markdown]
# <div class="optional">
#
# ## Homework - Monte-Carlo simulation [$\star$]
#
# Extend the calculation of $\pi$ example from class to use a sphere within a box of unit size, i.e. with one corner at the origin $(0,0,0)$ and the other corners at
# $(1,0,0)$, $(0,1,0)$, ..., $(1,1,1)$.
#
# </div>

# %% [markdown]
# ### Solution - Monte-Carlo simulation
#
# This time we consider a sphere inside a box.
#
# This method consists of drawing a square with an inner circle. We then generate a large number of random points within the square and count how many fall in the enclosed circle:
#
# Let's consider the unit box with one corner at the origin $(0,0,0)$ and the other corners at
# $(1,0,0)$, $(0,1,0)$, ..., $(1,1,1)$.
#
# The sphere that sits inside this box is centred at $(1/2, 1/2, 1/2)$ and has radius 1/2.
#
# The volume of the box is 1, the volume of the sphere is $(4/3)\pi r^3 = (4/3)\pi (1/8) = \pi/6$,
# and hence the ratio of the sphere to the box is also $\pi/6$.
#
# We therefore expect the probability $P$ of each point that lies inside the box to also lie in the sphere to be $\pi/6$ and so
#
# $$\pi = 6P = 6 \cdot \frac{\text{points inside the circle}}{\text{total points}}$$

# %%
import random

n_total = 1_000_000  # total number of points, selected to lie in box
x = np.random.uniform(low=0, high=1, size=n_total)
y = np.random.uniform(low=0, high=1, size=n_total)
z = np.random.uniform(low=0, high=1, size=n_total)

# square of distance from the centre of the sphere, (1/2, 1/2, 1/2)
r2 = ((x-0.5)**2) + ((y-0.5)**2) + ((z-0.5)**2) 

n_circle = sum(r2 <= (0.5**2))  # number of points falling in the circle
pi_estimate = 6 * n_circle/n_total

print(f'The estimate of pi is {pi_estimate}.')
# Out:
# The estimate of pi is 3.142494.

# %% [markdown]
# ## Homework - Naive Bayes classifier
#
#
# Repeat the naive Bayes classification for the Iris dataset, but use [sklearn.model_selection.train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) to split the dataset into test and training sets, using the training set for training and test set to calculate the accuracy in the end.
#
# Below is the code and application from class that gave an accuracy of 96%.
#
# If we more correctly split our training and test data how might we expect our accuracy to change?

# %%
# Calculate the means and standard deviations for our four features and three species
means = irisdf.groupby('target').mean().to_numpy()
stds = irisdf.groupby('target').std().to_numpy()


# Define the normal distributions for each
distributions = []
for mvec, sdvec in zip(means, stds):
    distributions.append([st.norm(m, sd) for m, sd in zip(mvec, sdvec)])

# Since the smallest measurement in the dataset is 0.1 cm,
# we use the range (x-eps) - (x+eps) (with eps=0.05) to calculate the probability.
def calc_probability(x, distribution, eps=0.05):
    # use the cdf = cumulative density function
    return distribution.cdf(x+eps) - distribution.cdf(x-eps)

def cls_probablility(data, cls, distributions):
    # initialise p - as we're going to be multiplying probabilities, initialise it to 1
    p = 1
    # for every feature, calculate its probability and multiply the results together
    for feat in range(4):
        p *= calc_probability(data[feat], distributions[cls][feat])    
    return p



def calc_likelihood(data):
    class_probs = []
    for cls in range(3):
        p = cls_probablility(data, cls, distributions)
        class_probs.append(p)
    return class_probs



# Subscripting to remove the last column which is the target variable
# these are therefore the means and stds of the entire 150 rows of data, 
# i.e. all of our measurements
means = irisdf.mean().to_numpy()[0:4]
stds = irisdf.std().to_numpy()[0:4]

prior_dists = [st.norm(m, s) for m, s in zip(means, stds)]

def calc_prior_X(data):
    p = 1
    for feat in range(4):
        p *= calc_probability(data[feat], prior_dists[feat])
    return p


def calc_naive_bayes(data):
    likelihood = calc_likelihood(data)
    # From the data, we know that all three classes are equally likely
    class_prior = [0.33, 0.33, 0.33]
    data_prior = calc_prior_X(data)
    
    class_densities = [(l*cp) / data_prior for l, cp in zip(likelihood, class_prior)]
    class_probs = [cd / sum(class_densities) for cd in class_densities]
    
    return class_probs



# Now we will be using our trained model to do inference 
predictions = [np.argmax(calc_naive_bayes(X)) for X in iris['data']]

correct_predictions = [1 if prediction==target else 0 for prediction, target in zip(predictions, iris['target'])]

accuracy = float(sum(correct_predictions)/len(correct_predictions))

print(f'Accuracy = {accuracy}')
# Out:
# Accuracy = 0.96

# %% [markdown]
# ### Solution - Naive Bayes classifier

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(irisdf, test_size=0.25)

# without a random_state option in the above you will get a different partitioning of the data
# into training and test datasets every time you run and so get different final accuracies.

# %%
# means and stds for the full data
means = irisdf.groupby('target').mean().to_numpy()
stds = irisdf.groupby('target').std().to_numpy()

print(means)
print(stds)

# means and stds for the training data
means = train.groupby('target').mean().to_numpy()
stds = train.groupby('target').std().to_numpy()

print(means)
print(stds)

# means and stds for the testing data
means = test.groupby('target').mean().to_numpy()
stds = test.groupby('target').std().to_numpy()

print(means)
print(stds)
# Out:
# [[5.006 3.428 1.462 0.246]
#  [5.936 2.77  4.26  1.326]
#  [6.588 2.974 5.552 2.026]]
# [[0.35248969 0.37906437 0.173664   0.10538559]
#  [0.51617115 0.31379832 0.46991098 0.19775268]
#  [0.63587959 0.32249664 0.5518947  0.27465006]]
# [[5.01944444 3.41666667 1.45       0.25277778]
#  [6.0025641  2.79230769 4.2974359  1.33076923]
#  [6.58108108 2.97297297 5.52432432 2.02702703]]
# [[0.33365461 0.39460649 0.17154758 0.09996031]
#  [0.48367409 0.28133574 0.42518552 0.18517964]
#  [0.56707722 0.27350467 0.54334632 0.26837851]]
# [[4.97142857 3.45714286 1.49285714 0.22857143]
#  [5.7        2.69090909 4.12727273 1.30909091]
#  [6.60769231 2.97692308 5.63076923 2.02307692]]
# [[0.4084277  0.34799267 0.1817195  0.12043876]
#  [0.58137767 0.41582339 0.60842569 0.24679767]
#  [0.82811185 0.44750018 0.59074052 0.30318819]]

# %%
# repeat the exercise above, but use the appropriate training and testing data
means = train.groupby('target').mean().to_numpy()
stds = train.groupby('target').std().to_numpy()

# Define the normal distributions for each
distributions = []
for mvec, sdvec in zip(means, stds):
    distributions.append([st.norm(m, sd) for m, sd in zip(mvec, sdvec)])

# Since the smallest measurement in the dataset is 0.1 cm,
# we use the range (x-eps) - (x+eps) (with eps=0.05) to calculate the probability.
def calc_probability(x, distribution, eps=0.05):
    # use the cdf = cumulative density function
    return distribution.cdf(x+eps) - distribution.cdf(x-eps)

def cls_probablility(data, cls, distributions):
    # initialise p - as we're going to be multiplying probabilities, initialise it to 1
    p = 1
    # for every feature, calculate its probability and multiply the results together
    for feat in range(4):
        p *= calc_probability(data[feat], distributions[cls][feat])    
    return p

def calc_likelihood(data):
    class_probs = []
    for cls in range(3):
        p = cls_probablility(data, cls, distributions)
        class_probs.append(p)
    return class_probs



# Subscripting to remove the last column which is the target variable
# these are therefore the means and stds of the entire 150 rows of data, 
# i.e. all of our measurements
means = train.mean().to_numpy()[0:4]
stds = train.std().to_numpy()[0:4]

prior_dists = [st.norm(m, s) for m, s in zip(means, stds)]

def calc_prior_X(data):
    p = 1
    for feat in range(4):
        p *= calc_probability(data[feat], prior_dists[feat])
    return p


def calc_naive_bayes(data):
    likelihood = calc_likelihood(data)
    # From the data, we know that all three classes are equally likely
    class_prior = [0.33, 0.33, 0.33]
    data_prior = calc_prior_X(data)
    
    class_densities = [(l*cp) / data_prior for l, cp in zip(likelihood, class_prior)]
    class_probs = [cd / sum(class_densities) for cd in class_densities]
    
    return class_probs

# %%
# Test on the training data set
predictions = [np.argmax(calc_naive_bayes(X)) for X in train.to_numpy()[:,:4]]
correct_predictions = [1 if prediction==target else 0 for prediction, target in zip(predictions, train.to_numpy()[:,4])]
accuracy = float(sum(correct_predictions)/len(correct_predictions))
print(f'Accuracy = {accuracy}')
# Out:
# Accuracy = 0.9732142857142857

# %%
# but now test on the testing data set
predictions = [np.argmax(calc_naive_bayes(X)) for X in test.to_numpy()[:,:4]]
correct_predictions = [1 if prediction==target else 0 for prediction, target in zip(predictions, test.to_numpy()[:,4])]
accuracy = float(sum(correct_predictions)/len(correct_predictions))
print(f'Accuracy = {accuracy}')
# Out:
# Accuracy = 0.9210526315789473

# %% [markdown]
# When I ran this, I got an accuracy for the training data of 0.97, and for the (unseen) test data 0.92.

# %% [markdown]
# <div class="advanced">
#
# ## Homework -  Maximum likelihood estimation  [$\star\star$]
#
# Investigate what happens if we don't use all 100 chips in the MLE example from class.
#
# Generalise the example so you seek to minimise the negative log likelihood instead of maximising the likelihood.
#
# </div>

# %% [markdown]
# ### Solution -  Maximum likelihood estimation

# %%
import random
import math

random.seed(42)


def draw(frac_red, k=20):
    # draw k chips from the bag comprising frac_red*100 red chips
    # and (1-frac_red)*100 green chips
    return random.sample(['red']*int(frac_red*100) + ['green']*int((1-frac_red)*100), k=k)


def calc_prob_single(outcome, frac_red):
    # caluclate the probability of "outcome" occurring given
    # fraction of red chips 
    assert(outcome in ('red', 'green'))
    if outcome == "red":
        return frac_red
    else:
        return 1 - frac_red


def update_frac(frac_red, total, result):
    # update the remaining chips in order to update the
    # fraction red value
    nums = [int(frac_red * total), int((1-frac_red) * total)]

    if result == "red":
        nums[0]-= 1
    else:
        nums[1]-= 1
    return float(nums[0]/sum(nums))


def calc_prob(results, frac_red, total):
    prob = 1
    for result in results:
        p = calc_prob_single(result, frac_red)
        prob *= p
        frac_red = update_frac(frac_red, total, result)
        
    return prob


TRUE_PROPORTION = 0.6

# Here we draw 100 chips from the bag, using the true proportion.
results = draw(TRUE_PROPORTION, k=100)

# From this point forth, we will only use the drawn chips in an attempt
# to estimate the true proportion of chips. 

# Possible values of the proportion: 0.0, 0.1, 0.2, 0.3, ...., 0.9, 1.0
allks = [x/10 for x in range(0, 11)]

# Calculate the probability of observing this data (i.e. likelihood), 
# for each value of the proportion
# use n_chips
n_chips = 20
probs = [calc_prob(results[0:n_chips], x, 100) for x in allks]

print(probs)

print('Likelihood maximised at:', allks[np.argmax(probs)])

plt.clf()
plt.plot(allks, probs, 'k.-')
plt.show()
# Out:
# [-0.0, -0.0, 2.4300973216649216e-11, 6.137985937021722e-09, 1.2635391528814635e-07, 8.789996957945375e-07, 1.28951910141748e-06, 6.007959545732754e-07, 4.551541376388765e-08, 2.2656779998364665e-11, -0.0]
# Likelihood maximised at: 0.6

# %%
from math import log

def calc_nll(results, frac_red, total):
    nll = 0
    for result in results:
        p = calc_prob_single(result, frac_red)
        # avoid taking log of zero
        nll += -log(max(p, 1.e-10))
        frac_red = update_frac(frac_red, total, result)
        
    return nll

# %%
TRUE_PROPORTION = 0.6

# Here we draw 100 chips from the bag, using the true proportion.
results = draw(TRUE_PROPORTION, k=100)

# From this point forth, we will only use the drawn chips in an attempt
# to estimate the true proportion of chips. 

# Possible values of the proportion: 0.0, 0.1, 0.2, 0.3, ...., 0.9, 1.0
allks = [x/10 for x in range(0, 11)]

# Calculate the probability of observing this data (i.e. likelihood), for each value of the proportion
n_chips = 80
nlls = [calc_nll(results[0:n_chips], x, 100) for x in allks]

print(nlls)

print('Neg log likelihood linimised at frac:', allks[np.argmin(nlls)])
plt.clf()
plt.plot(allks, nlls, 'k.-')
plt.show()
# Out:
# [1029.0402833453345, 832.5644148820575, 624.2650130686146, 411.23995350914925, 195.33967542581252, 58.88178980970234, 67.37107232534534, 184.74140830092117, 417.32392183161284, 623.7410761094354, 798.9314167562709]
# Neg log likelihood linimised at frac: 0.5

# %% [markdown]
# ## Homework - The logistic function and its derivative
#
# Plot the logistic function
#
# $$
# \sigma(z) = \frac{1}{1+e^{-z}}
# $$
#
# Compute and plot its derivative over the interval $z \in [-10,10]$.
#
# How would you update this function so that it was centred at $z=5$, and had a "tighter" (i.e. faster) jump from zero to one?

# %% [markdown]
# ### Solution - The logistic function and its derivative

# %%
fig = plt.figure(figsize=(10, 6))
ax1 = plt.subplot(111)

ax1.set_title('Logistic function', fontsize=16)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$\sigma(x)$', fontsize=16)

def logistic_fun(x):
    return 1 / (1 + np.exp(-x))

# define our x for plotting purposes
x = np.linspace(-10., 10., 1000)

# plot our function
ax1.plot(x, logistic_fun(x), 'k', lw=2, label='Logistic function')

# %% [markdown]
# A derivation of the derivative can be seen here <https://en.wikipedia.org/wiki/Logistic_function#Derivative> and requires use of the [quotient rule](https://en.wikipedia.org/wiki/Quotient_rule) of differentiation after noting that
#
# $$
# \sigma(z) := \frac{1}{1+e^{-z}} \equiv \frac{e^{z}}{e^{-z}+1}
# $$
#
# Then
#
# $$
# \frac{d \sigma(z)}{dz} := \frac{e^{z}}{(1+e^{z})^2}
# $$

# %%
fig = plt.figure(figsize=(10, 6))
ax1 = plt.subplot(111)

ax1.set_title('d(Logistic function)/dx', fontsize=16)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$d\sigma(x)/dx$', fontsize=16)

def dlogistic_fun(x):
    return np.exp(x) / (1 + np.exp(x))**2

# define our x for plotting purposes
x = np.linspace(-10., 10., 1000)

# plot our function
ax1.plot(x, dlogistic_fun(x), 'k', lw=2, label='Logistic function derivative')

# %%
fig = plt.figure(figsize=(10, 6))
ax1 = plt.subplot(111)

ax1.set_title('Logistic function and its derivative', fontsize=16)
ax1.set_xlabel('$x$', fontsize=16)

# define our x for plotting purposes
x = np.linspace(-10., 10., 1000)

# plot our functions
ax1.plot(x, logistic_fun(x), 'k', lw=2, label='Logistic function')
ax1.plot(x, dlogistic_fun(x), 'r', lw=2, label='Logistic function')
ax1.legend(loc='best', fontsize=10)

# %% [markdown]
# To shift and tighten the jump we need to make two changes to the formula:

# %%
fig = plt.figure(figsize=(10, 6))
ax1 = plt.subplot(111)

ax1.set_title('Logistic function', fontsize=16)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$\sigma(x)$', fontsize=16)

def logistic_fun_shift_tight(x):
    return 1 / (1 + np.exp(-10*(x-5)))

# define our x for plotting purposes
x = np.linspace(-10., 10., 1000)

# plot our function
ax1.plot(x, logistic_fun_shift_tight(x), 'k', lw=2, label='Logistic function')

# %% [markdown]
# ## Homework - PCA for the Iris dataset [$\star\star$]
#
# We saw in lecture 3 the singular value decomposition (SVD), and I noted that it's closely related to the concept of principal component analysis (PCA).
#
# Read through this material on the application of PCA - see the links in the lecture notebook as well as this application to the Iris dataset
#
# - <https://www.kaggle.com/shrutimechlearn/step-by-step-pca-with-iris-dataset>
#
# See also
#
# - <https://scikit-learn.org/stable/auto_examples/decomposition/plot_pca_iris.html>
# - <https://scikit-learn.org/stable/modules/decomposition.html#pca>
#
#
# <br>
#
# As a reminder on one of the links I gave earlier on the PCA in general, take a look at:
#
# - * [PCA for Dummies](http://www.billconnelly.net/?p=697)
#
# <br>
# <br>
#
# ### Try implementing things yourself to "demystify" a little what scikit-learn is doing under the hood
#
# As well as reading through you could try recreating the scikit-learn PCA results for the Iris data set - try reducing the dimension from 4 features to 2. You could try via an SVD calculation (cf. L3), or you could try baed on computing the e'vals and e'vectors of the covariance matrix.

# %% [markdown]
# ### Solution - PCA for the Iris dataset - first via SVD
#
# First let's take the SVD route - recall from a previous lecture:
#
# <br>
#
#
# The [Singular Value Decomposition](https://en.wikipedia.org/wiki/Singular_value_decomposition) generalises the eigen-decomposition concept to non-square matrices.
#
# Consider an arbitrary $m \times n$ real matrix $A$ - very similar to the square case it can be decomposed into a product of three matrices:
#
# $$A = U\Sigma V^{T}$$
#
# where
#
#
# - $U$ is an $m\times m$ orthogonal matrix - its columns are the eigenvectors of the matrix $AA^T$,
#
#
# - $V$ is an $n\times n$ orthogonal matrix - its columns are the eigenvectors of the matrix $A^TA$,
#
#
# - $\Sigma$ is an $m\times n$ diagonal matrix whose diagonal entries, $\sigma_1, \sigma_2,\ldots  $ are what are called the ***singular values*** of $A$.
#
#
# <br>
#
#
# <br>
#
# The singular values of $A$ are positive, and the convention is to number them/place down the diagonal of $\Sigma$ in order of their magnitude: $\sigma_1\geq\sigma_2\geq\ldots\geq 0$.
#
# <br>
#
# The singular values are the square roots of the eigenvalues of the square matrix $A^TA$.  They are also the square roots of the eigenvalues of the square matrix $AA^T$.
#
#
# <br>
# <br>
#
# If we expand out this priduct of three matrices we get
#
# $$A = U\Sigma V^{T} = \sigma_1 u_{:1} v_{:1}^T +  \sigma_2 u_{:2} v_{:2}^T + \ldots $$

# %%
# First let's use scitkit-learn's PCA functionality to reduce the 
# data dimension from 4 features to 2 - then we'll recreate the result
# ourselves without use of scikit-learn

from sklearn.datasets import load_iris
from sklearn import decomposition 

iris = load_iris()

X = iris.data
y = iris.target

fig = plt.figure(figsize=(12, 5))
ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

pca = decomposition.PCA(n_components=2)
pca.fit(X)
Xp = pca.transform(X)
print(np.shape(Xp))

target_names = iris.target_names
colors = ["navy", "turquoise", "darkorange"]

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax1.scatter(
        Xp[y == i, 0], Xp[y == i, 1], color=color, alpha=0.8, label=target_name)
ax1.legend(loc="best")
ax1.set_title("PCA(dimensions=2) of the IRIS dataset")

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax2.scatter(
        X[y == i, 0], X[y == i, 1], color=color, alpha=0.8, label=target_name)
ax2.legend(loc="best")
ax2.set_title("Compare with just plotting first two features")
# Out:
# (150, 2)
# Text(0.5, 1.0, 'Compare with just plotting first two features')

# %%
# let's try to demystify a bit but trying to 
# calculate from our own SVD

X = iris.data
y = iris.target

print(pca.fit(X))

# Based on L3 homework:
import scipy.linalg as sl
from pprint import pprint

# start by subtracting the means of the columns
Xc = X - X.mean(axis=0, keepdims=True)

UU, SS, VVT = sl.svd(Xc)
SSS = np.zeros_like(X,dtype='float')
# the following just places the SS vector on singular vectors into the 
# right locations of the matrix SSS
SSS[:min(X.shape[0],X.shape[1]),:min(X.shape[0],X.shape[1])] = np.diag(SS)

# check that we have a successful SVD
print(np.allclose(Xc, UU @ SSS @ VVT))

# what are the singular values
print('singular vals = ', SS)

# think about the shapes of these matrices
print(np.shape(Xc))
print(np.shape(VVT[:2,:].T))

# perform the PCA projection through the following multiplication
# remember here we have features as the columns and data points as the rows
Xp =   Xc @ VVT[:2,:].T
# should now be of shape 150x2
print(np.shape(Xp))

# let's plot and compare with above
fig = plt.figure(figsize=(6, 5))
ax1 = plt.subplot(111)

target_names = iris.target_names
colors = ["navy", "turquoise", "darkorange"]

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax1.scatter(
        Xp[y == i, 0], Xp[y == i, 1], color=color, alpha=0.8, label=target_name)
ax1.legend(loc="best")
ax1.set_title("Our PCA via SVD")
# Out:
# PCA(n_components=2)
# True
# singular vals =  [25.09996044  6.01314738  3.41368064  1.88452351]
# (150, 4)
# (4, 2)
# (150, 2)
# Text(0.5, 1.0, 'Our PCA via SVD')

# %% [markdown]
# [For a reminder on what the projection operation in above is doing, take a look at the homework exercise on the project matrix in Linear Algebra 1].
#
# <br>
#
# The result we have above isn't quite right is it (at least when I run things - it's similar but has different trends)?
#
# Let's print what scikit-learn thinks what we call the leading singular values and e-vectors are and compare against ours

# %%
X = iris.data
y = iris.target

pca = decomposition.PCA(n_components=2)
pca.fit(X)

# %precision 5

pprint(pca.singular_values_)
pprint(pca.components_.T)

# and these are our full S and V matrices
pprint(SS)
pprint(VVT.T)
# Out:
# array([25.09996,  6.01315])
# array([[ 0.36139,  0.65659],
#        [-0.08452,  0.73016],
#        [ 0.85667, -0.17337],
#        [ 0.35829, -0.07548]])
# array([25.09996,  6.01315,  3.41368,  1.88452])
# array([[ 0.36139, -0.65659,  0.58203,  0.31549],
#        [-0.08452, -0.73016, -0.59791, -0.31972],
#        [ 0.85667,  0.17337, -0.07624, -0.47984],
#        [ 0.35829,  0.07548, -0.54583,  0.75366]])

# %% [markdown]
# We have the same issue we saw previously (L3 homework), where there is a sign difference in the second of the e'vectors (again for me when I ran this - for you with a different library version you might get a different answer).
#
# Let's flip the sign and try again:

# %%
VVT[1,:] = -VVT[1,:]
print(VVT[:2,:].T)
# Out:
# [[ 0.36139  0.65659]
#  [-0.08452  0.73016]
#  [ 0.85667 -0.17337]
#  [ 0.35829 -0.07548]]

# %%
# try projecting and plotting again:

Xp =   Xc @ VVT[:2,:].T
print(np.shape(Xp))

# let's plot and compare with above
fig = plt.figure(figsize=(6, 5))
ax1 = plt.subplot(111)

target_names = iris.target_names
colors = ["navy", "turquoise", "darkorange"]

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax1.scatter(
        Xp[y == i, 0], Xp[y == i, 1], color=color, alpha=0.8, label=target_name)
ax1.legend(loc="best")
ax1.set_title("Our PCA via SVD")
# Out:
# (150, 2)
# Text(0.5, 1.0, 'Our PCA via SVD')

# %%
# looks the same from the plot, let's take a look at some values

# our first 10 transformed data points
print(Xp[:10,:])
# scikit-learns
print(pca.transform(X)[:10,:])
# Out:
# [[-2.68413  0.3194 ]
#  [-2.71414 -0.177  ]
#  [-2.88899 -0.14495]
#  [-2.74534 -0.3183 ]
#  [-2.72872  0.32675]
#  [-2.28086  0.74133]
#  [-2.82054 -0.08946]
#  [-2.62614  0.16338]
#  [-2.88638 -0.57831]
#  [-2.67276 -0.11377]]
# [[-2.68413  0.3194 ]
#  [-2.71414 -0.177  ]
#  [-2.88899 -0.14495]
#  [-2.74534 -0.3183 ]
#  [-2.72872  0.32675]
#  [-2.28086  0.74133]
#  [-2.82054 -0.08946]
#  [-2.62614  0.16338]
#  [-2.88638 -0.57831]
#  [-2.67276 -0.11377]]

# %% [markdown]
# ### Solution - Now instead starting from the covariance matrix
#
# Now try from the starting point of computing the covariance matrix ....

# %%
# Subtract the mean from each column
Xc = X - X.mean(axis=0, keepdims=True)

# Covariance matrix should then be defined as (1/(n-1)) X.T @ X  
C = (1/(Xc.shape[0]-1)) * Xc.T @ Xc

# Calculate eigenvalues of covariance matrix
lam, vecs = sl.eig(C)

print(np.real(lam))

# Choose the first two eigenvectors by extracting first two columns
P = vecs[:,:2]

print(P)

# Fix same sign issue as above
P[:,1] = -P[:,1]

# Project
Xp = Xc @ P

# let's plot and compare with above
fig = plt.figure(figsize=(6, 5))
ax1 = plt.subplot(111)

target_names = iris.target_names
colors = ["navy", "turquoise", "darkorange"]

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    ax1.scatter(
        Xp[y == i, 0], Xp[y == i, 1], color=color, alpha=0.8, label=target_name)
ax1.legend(loc="best")
ax1.set_title("Our PCA via SVD")
# Out:
# [4.22824 0.24267 0.07821 0.02384]
# [[ 0.36139 -0.65659]
#  [-0.08452 -0.73016]
#  [ 0.85667  0.17337]
#  [ 0.35829  0.07548]]
# Text(0.5, 1.0, 'Our PCA via SVD')

# %% [markdown]
# ### Solution - The annoying sign issue
#
# This sign issue might seem really unsatisfactory - in an earlier lecture when it came up in the context of SVD I pointed you at
#
# - <https://math.stackexchange.com/questions/2359992/how-to-resolve-the-sign-issue-in-a-svd-problem>
#
# Here for PCA I point to
#
# - <https://stats.stackexchange.com/questions/88880/does-the-sign-of-scores-or-of-loadings-in-pca-or-fa-have-a-meaning-may-i-revers>
#
# and a description of the fact that Matlab enforces a convention such that "the largest component (by absolute magnitude) in each right singular vector/eigenvector will be positive (there are other possible conventions as well that also resolve this ambiguity)":
#
# - <https://www.mathworks.com/matlabcentral/answers/300899-sign-difference-between-coeff-pca-x-and-v-svd-x>
#
#
# <br>
#
#
# For the same thing in scikit-learn see:
#
# - <https://stackoverflow.com/questions/44765682/in-sklearn-decomposition-pca-why-are-components-negative>
#
# and here:
#
# - <https://github.com/scikit-learn/scikit-learn/blob/main/sklearn/utils/extmath.py>
#
# the doc
#
#         flip_sign : bool, default=True
#
#         The output of a singular value decomposition is only unique up to a
#         permutation of the signs of the singular vectors. If `flip_sign` is
#         set to `True`, the sign ambiguity is resolved by making the largest
#         loadings for each component in the left singular vectors positive.
#
# and the function `svd_flip`
